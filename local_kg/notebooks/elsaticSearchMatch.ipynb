# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../dataset/entityData/WikidataLabel_clean_noise.csv', encoding='utf-8')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38570587 entries, 0 to 38570586
# Data columns (total 2 columns):
# qValue           object
# wikidataLabel    object
# dtypes: object(2)
# memory usage: 588.5+ MB

# %%
qDict = dict(zip (df.qValue, df.wikidataLabel))
qDict
# Out:
# {u'Q15140124': u'category in asia',
#  u'Q15140125': u'category user prl 3',
#  u'Q15140122': u'category <NUMBER> in europe',
#  u'Q48196969': u'botulinum toxin a in postherpetic neuralgia a parallel randomized double blind single dose placebo controlled trial',
#  u'Q15140121': u'category user script developers',
#  u'Q48196967': u'contribution of intraoperative radiotherapy iort for therapeutic de escalation in early breast cancer report of a single institution s experience',
#  u'Q48196966': u'anastassiya krestova',
#  u'Q48196965': u'pd programmed death ligand 1 protects against experimental intracerebral hemorrhage induced brain injury',
#  u'Q48196964': u'cingulotomy in a case of concomitant obsessive compulsive disorder and tourette s syndrome',
#  u'Q48196963': u'ab initio and density functional theory dft studies on triflic acid with water and protonated water clusters',
# ...

# %%
df_es = pd.read_csv('../../dataset/entityData_Sep/elasticsearch_proc_ish.csv', encoding='utf-8', header=None,)
df_es.head(50)
# Out:
# ParserErrorTraceback (most recent call last)
# <ipython-input-82-c31c3a0f4f1b> in <module>()
# ----> 1 df_es = pd.read_csv('../../dataset/entityData_Sep/elasticsearch_proc_ish.csv', encoding='utf-8', header=None)
#       2 df_es.head(50)
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# ...

# %%
def qValuetoDict(qValue):
    qValue = str(qValue).strip()
    if qValue in qDict:
        return qDict[qValue]


df_es.iloc[:,2:5]=df_es.iloc[:,2:5].applymap(qValuetoDict)

# %%
df_es.head(2), df_es.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 733901 entries, 0 to 733900
# Data columns (total 5 columns):
# 0    729890 non-null object
# 1    732607 non-null object
# 2    725450 non-null object
# 3    723309 non-null object
# 4    723189 non-null object
# dtypes: object(5)
# memory usage: 28.0+ MB
# (                         0                         1  \
#  0  austroasiatic languages  austro asiatic languages
#  1                mon–khmer  austro asiatic languages
#
#                                    2                                 3  \
#  0  category austroasiatic languages  template austroasiatic languages
#  1                             khmer                             khmer
#
#                           4
#  0  austrasiatica langfordi
#  1                    khmer  , None)

# %%
df_es['isMatch'] = df_es[1].str.strip() == df_es[2].str.strip()

# %%
df_es['isMatch'].count() - sum(df_es['isMatch']) #36k ahmed
# Out:
# 363770

# %%
sum(df_es['isMatch'])
# Out:
# 370131

# %%
df_es.head(40)
# Out:
#                           0                           1  \
# 0   austroasiatic languages    austro asiatic languages
# 1                 mon–khmer    austro asiatic languages
# 2           language family             language family
# 3            southeast asia              southeast asia
# 4                     india                       india
# 5                bangladesh                  bangladesh
# 6                     nepal                       nepal
# 7                     china  people s republic of china
# 8             austroasiatic    austro asiatic languages
# 9                     latin              roman alphabet
# 10                     asia                        asia
# 11               south asia                  south asia
# 12               vietnamese                  vietnamese
# 13                    khmer                       khmer
# 14                      mon                         mon
# 15         recorded history            recorded history
# ...
